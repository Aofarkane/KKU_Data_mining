# %% [markdown]
# <a href="https://colab.research.google.com/github/Aofarkane/KKU_Data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab  import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# os for ทำงานเกี่ยวกับไฟล์
import os
# pd เพื่อเรียกใช้ตาราง ในไฟล์
import pandas as pd
# สร้างตัวแปลในชื่อ base_path path คือที่ที่เก็บข้อมูลของเราเอง
base_path = '/content/drive/My Drive/DWDM_material'
# เรียกใช้ไฟล์ในโฟเดอร์
data = pd.read_csv(os.path.join(base_path,'test.csv'))
# show เเค่หัวตาราง
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# ## Box plot

# %%
from matplotlib import  pyplot as plt

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6a72f270f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6a72f27b00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6a72f305c0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6a72f30240>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6a72f27400>,
#   <matplotlib.lines.Line2D at 0x7f6a72f27780>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6a72fa9d68>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6a72fb87b8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6a72fc3278>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6a72fb8eb8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6a72fb80b8>,
#   <matplotlib.lines.Line2D at 0x7f6a72fb8438>]}

# %%
plt.boxplot(data['x'],vert=False,whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6a72f0e2b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6a72f0ecc0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6a72f1b780>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6a72f1b400>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6a72f0e5c0>,
#   <matplotlib.lines.Line2D at 0x7f6a72f0e940>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %% [markdown]
# ##scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=1)

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='*')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='*',alpha=0.6)

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='*',alpha=0.6)
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6)

# %% [markdown]
# ##HW วาดปีกกับงา ให้น้อนไดโนเสาร์
